# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
seeds = [1, 88, 94, 31, 24, 79, 86, 66, 3, 22]

# %%
Ujj = {'R2': [0.8228420230020843,
  0.35752881586071983,
  0.6322696291984223,
  0.4791118401628651,
  0.5845840395258621,
  0.3485820549114085,
  0.39036961397360637,
  0.5191447383699413,
  0.724783978301321,
  0.8750823457047044],
'RMSE': [0.5932453469245561,
  0.7682282034070852,
  0.6707226784948654,
  0.8973313442049229,
  0.6990094501947961,
  0.9569292170110283,
  0.870486108995358,
  0.8141673837262783,
  0.5166396411202012,
  0.4229149688184802] }

# %%
myres = {'R2':[0.7088401317596436,
               0.4096532464027405,
               0.34192991256713867,
               0.4313206672668457,
               0.7676728963851929,
               0.39783090353012085,
               0.46086156368255615,
               0.4109424352645874,
               0.6752837896347046,
               0.7450339794158936],
         
         'RMSE':[0.7605364699853254,
                 0.7364049276135952,
                 0.8972526637816132,
                 0.9375930422071495,
                 0.5227462562816273,
                 0.9200458642085738,
                 0.8186114876983203,
                 0.9011264533281083,
                 0.5611800160755619,
                 0.6042022861496064]}

# %%
import matplotlib.pyplot as plt
import numpy as np

seeds = [1, 88, 94, 31, 24, 79, 86, 66, 3, 22]

GPR = {'R2': [0.8228420230020843, 0.35752881586071983, 0.6322696291984223, 0.4791118401628651, 0.5845840395258621, 0.3485820549114085, 0.39036961397360637, 0.5191447383699413, 0.724783978301321, 0.8750823457047044],
       'RMSE': [0.5932453469245561, 0.7682282034070852, 0.6707226784948654, 0.8973313442049229, 0.6990094501947961, 0.9569292170110283, 0.870486108995358, 0.8141673837262783, 0.5166396411202012, 0.4229149688184802]}

Trans = {'R2': [0.7088401317596436, 0.4096532464027405, 0.34192991256713867, 0.4313206672668457, 0.7676728963851929, 0.39783090353012085, 0.46086156368255615, 0.4109424352645874, 0.6752837896347046, 0.7450339794158936],
         'RMSE': [0.7605364699853254, 0.7364049276135952, 0.8972526637816132, 0.9375930422071495, 0.5227462562816273, 0.9200458642085738, 0.8186114876983203, 0.9011264533281083, 0.5611800160755619, 0.6042022861496064]}

barWidth = 0.3
r1 = np.arange(len(seeds))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(12, 6))
plt.bar(r1, GPR['RMSE'], color='b', width=barWidth, edgecolor='grey', label='GPR')
plt.bar(r2, Trans['RMSE'], color='g', width=barWidth, edgecolor='grey', label='TransPolymer')

plt.xlabel('Seed', fontweight='bold')
plt.ylabel('RMSE Score', fontweight='bold')
plt.xticks([r + barWidth/2 for r in range(len(seeds))], seeds)
plt.title('RMSE Scores', fontweight='bold')
plt.legend()

plt.tight_layout()
plt.savefig('rmse.png')
plt.show()
